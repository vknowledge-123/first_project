# %% [raw]
# !pip install pandas

# %%
# !pip install --upgrade pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 470.9 kB/s eta 0:00:00MB/s eta 0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 5.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.2.1 which is incompatible.
# ...

# %% [markdown]
# # Read CSV Files:

# %% [raw]
# A simple way to store big data sets is to use CSV Files (Comma Separated files)
# CSV files contains plain text and is a well know format that can be read by everyone includind pandas.

# %%
import pandas as pd
df = pd.read_csv("/home/vaishnavilapi/Downloads/data.csv")
print(df)
# print the DataFrame without the using any method:prints only first 5 and last 5
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# using to_string()method
import pandas as pd
df = pd.read_csv("/home/vaishnavilapi/Downloads/data.csv")
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# max Rows : you can check your systems maximum rows with the 
# pd.options.display.max_row statement

import pandas as pd
print(pd.options.display.max_rows)

'''here the number is 60, which means that if yhe dataframe contains more than 60 rows ,
the print(df) statement will return only the headers and the first and lst 5 rows.
you can change the maximum rows number with the same statement.'''
# Out:
# 60
# 'here the number is 60, which means that if yhe dataframe contains more than 60 rows ,\nthe print(df) statement will return only the headers and the first and lst 5 rows.\nyou can change the maximum rows number with the same statement.'

# %%
import pandas as pd
pd.options.display.max_rows = 9999
df = pd.read_csv("/home/vaishnavilapi/Downloads/data.csv")
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [raw]
# Read JSON bid data sets are often stored,or extracted as JSON.
# JSON is plain text, but has the format of an object, and is well known in the world in the of programming ,including pandas.

# %%
import pandas as pd
df = pd.read_json("/home/vaishnavilapi/Downloads/data.json")
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
'''if you JSON code is not in a file , but in a python dictionary you can load it in Dataframe directly.'''

import pandas as pd
data ={
    "Duration":{
        "0" : 60,
        "1" : 60,
        "2" : 60,
        "3" : 45,
        "4" : 45,
        "5" : 60,
    },
    "Python":{
        "0" : 60,
        "1" : 60,
        "2" : 60,
        "3" : 45,
        "4" : 45,
        "5" : 60,
    },
    "Maxpulse":{
        "0" : 130,
        "1" : 145,
        "2" : 125,
        "3" : 148,
        "4" : 138,
        "5" : 251,
    },
    "Calories":{
        "0" : 409,
        "1" : 479,
        "2" : 340,
        "3" : 282,
        "4" : 406,
        "5" : 300,
}
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Python  Maxpulse  Calories
# 0        60      60       130       409
# 1        60      60       145       479
# 2        60      60       125       340
# 3        45      45       148       282
# 4        45      45       138       406
# 5        60      60       251       300

# %% [raw]
# Viewing the data:
#  The head() method returns the headers and a specified number of rows, startinf from the top

# %%
import pandas as pd
df = pd.read_csv("/home/vaishnavilapi/Downloads/data.csv")
print(df.head(5))
print(df.head(-5))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# ...

# %% [raw]
# There is also tail() method for viewing the last rows of the DataFrame, starting from the bottom.

# %%
import pandas as pd
df = pd.read_csv("/home/vaishnavilapi/Downloads/data.csv")
print(df.tail(5))
print(df.tail(-5))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#      Duration  Pulse  Maxpulse  Calories
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# ...

# %%
print(df.shape)
# Out:
# (169, 4)

# %%
import pandas as pd
